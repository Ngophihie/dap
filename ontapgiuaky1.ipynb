# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#      Country Name Country Code 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB          4309          4481          4930
# 2         Algeria          DZA         45692         44822         44136
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2008 [YR2008] 2009 [YR2009]     2010 [YR2010]     2011 [YR2011]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    1058 non-null   object
#  1   Series Code    1056 non-null   object
#  2   Country Name   1056 non-null   object
#  3   Country Code   1056 non-null   object
#  4   2005 [YR2005]  1056 non-null   object
#  5   2006 [YR2006]  1056 non-null   object
#  6   2007 [YR2007]  1056 non-null   object
#  7   2008 [YR2008]  1056 non-null   object
#  8   2009 [YR2009]  1056 non-null   object
#  9   2010 [YR2010]  1056 non-null   object
#  10  2011 [YR2011]  1056 non-null   object
#  11  2012 [YR2012]  1056 non-null   object
#  12  2013 [YR2013]  1056 non-null   object
#  13  2014 [YR2014]  1056 non-null   object
#  14  2015 [YR2015]  1056 non-null   object
#  15  2016 [YR2016]  1056 non-null   object
#  16  2017 [YR2017]  1056 non-null   object
# ...

# %%
#tạo DataFrame
df = pd.read_csv('data.csv')
print(df)
# Out:
#                                             Series Name  Series Code  \
# 0     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4     Air transport, registered carrier departures w...  IS.AIR.DPRT
# ...                                                 ...          ...
# 1056                                                NaN          NaN
# 1057                                                NaN          NaN
# 1058                                                NaN          NaN
# 1059   Data from database: World Development Indicators          NaN
# 1060                           Last Updated: 05/25/2021          NaN
#
#         Country Name Country Code 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# ...

# %%
# Xóa cột 'Country Name'
df = df.drop(columns=['Country Name'])
print("\nDataFrame sau khi xóa cột 'Country Name':")
print(df)
# Out:
# DataFrame sau khi xóa cột 'Country Name':
#                                             Series Name  Series Code  \
# 0     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3     Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4     Air transport, registered carrier departures w...  IS.AIR.DPRT
# ...                                                 ...          ...
# 1056                                                NaN          NaN
# 1057                                                NaN          NaN
# 1058                                                NaN          NaN
# 1059   Data from database: World Development Indicators          NaN
# 1060                           Last Updated: 05/25/2021          NaN
#
#      Country Code 2005 [YR2005] 2006 [YR2006] 2007 [YR2007] 2008 [YR2008]  \
# ...
